# %%
import requests
from pprint import pprint  # for better readability of the output
import pandas as pd
from pandas import json_normalize

# %%
url = "https://newsapi.org/v2/everything?from=2024-06-23&to=2024-07-23&q=2024&apiKey=fbe4cf3035f148c2a32bc54e5e5a9836"
response = requests.get(url)
data = response.json()
# num_articles = response.totalResults()
# pprint(data)
articles_df = json_normalize(data['articles'])
# newsapi_df = pd.DataFrame(data)
print (articles_df)
print (articles_df.columns)
# Out:
#            author                                              title  \
# 0           WIRED           The Best Hearing Aids for Seniors (2024)
# 1   Lawrence Bonk  Microsoft Notepad just got spellcheck in the y...
# 2       Kris Holt  What we expect from Samsung Unpacked 2024, inc...
# 3       Jeff Dunn          The best Prime Day AirPods deals for 2024
# 4    Amy Skorheim       The 19 best Prime Day speaker deals for 2024
# ..            ...                                                ...
# 95           None  Watch continuing coverage of the election camp...
# 96           None  Watch continuing coverage of the election camp...
# 97           None  Watch continuing coverage of the election camp...
# 98           None  Our dream is over and it's tough to take – Van...
# 99           None  'We're flying to Poland' - England fans scramb...
#
#                                           description  \
# 0   These WIRED-tested hearing aids, approved by a...
# ...
